# %% [markdown]
# # Common Spatial Patterns (CSP)

# %%
from opm_thesis.classifiers.csp.csp_functions import csp_classify

data_dir = "/Users/martin.iniguez/Desktop/master-thesis/opm-thesis/data/digits_epochs/freq_bands/"
id_pairs = [[2**i, 2**j] for i in range(3, 8) for j in range(i + 1, 8)]
freqs = ["all_data", "mid_freq", "alpha", "beta", "low_gamma", "high_gamma"]

# %% [markdown]
# ## Plotting CSP

# %%
from opm_thesis.classifiers.csp.csp_functions import plot_csp_patterns
id_pair = [32, 128]
plot_csp_patterns(id_pair, freqs[-2], data_dir, num=25, n_components=1, dim= "[X]")

# %%
plot_csp_patterns(id_pair, freqs[-2], data_dir, num=25, n_components=1, dim="[Y]")

# %%
plot_csp_patterns(id_pair,freqs[-2], data_dir, num=25, n_components=1, dim="[Z]")

# %% [markdown]
# ## Plotting Beta

# %%
plot_csp_patterns(id_pair, freqs[-3], data_dir, num=25, n_components=2, dim="[X]")

# %%
plot_csp_patterns(id_pair, freqs[-3], data_dir, num=25, n_components=2, dim="[X]")

# %%
plot_csp_patterns(id_pair, freqs[-3], data_dir, num=25, n_components=1, dim="[Y]")

# %%
plot_csp_patterns(id_pair, freqs[-3], data_dir, num=None, n_components=1, dim="[Z]")

# %%
plot_csp_patterns(id_pair, freqs[-3], data_dir, num=25, n_components=4, dim="[Z]")

# %% [markdown]
# ## Check classification of CSP

# %%
freq = freqs[-3]
print("Frequency band: ", freq)
for id_pair in id_pairs:
    csp_classify(id_pair=id_pair, freq=freq, num=25, dim="[X]", data_dir=data_dir)
# Out:
# Frequency band:  beta
# Computing scores for [1, 2] in beta band... Done. Average Score: 47.74%
# Computing scores for [1, 3] in beta band... Done. Average Score: 54.19%
# Computing scores for [1, 4] in beta band... Done. Average Score: 35.00%
# Computing scores for [1, 5] in beta band... Done. Average Score: 50.00%
# Computing scores for [2, 3] in beta band... Done. Average Score: 49.68%
# Computing scores for [2, 4] in beta band... Done. Average Score: 43.87%
# Computing scores for [2, 5] in beta band... Done. Average Score: 54.84%
# Computing scores for [3, 4] in beta band... Done. Average Score: 53.12%
# Computing scores for [3, 5] in beta band... Done. Average Score: 51.61%
# Computing scores for [4, 5] in beta band... Done. Average Score: 50.62%
