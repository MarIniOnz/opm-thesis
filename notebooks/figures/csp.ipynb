# %% [markdown]
# # Common Spatial Patterns (CSP)

# %%
from opm_thesis.classifiers.csp.csp_functions import csp_classify

data_dir = "./data/digits_epochs/freq_bands"
id_pairs = [[2**i, 2**j] for i in range(3, 8) for j in range(i + 1, 8)]
freqs = ["all_data", "mid_freq", "alpha", "beta", "low_gamma", "high_gamma", "ideal_beta"]

# %%
freq = freqs[-1]
print("Frequency band: ", freq)
for id_pair in id_pairs:
    scores, eigenvalues = csp_classify(
        id_pair=id_pair, freq=freq, num=90, dim="[X]", data_dir=data_dir
    )
# Out:
# Frequency band:  ideal_beta
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 4
#       2 print("Frequency band: ", freq)
#       3 for id_pair in id_pairs:
# ----> 4     scores, eigenvalues = csp_classify(
#       5         id_pair=id_pair, freq=freq, num=90, dim="[X]", data_dir=data_dir
#       6     )
#
# File ~/Martin/opm-thesis/opm_thesis/classifiers/csp/csp_functions.py:48, in csp_classify(id_pair, freq, data_dir, num, dim, n_components, normalize_data)
#      45     epochs = pickle.load(f)
#      46     epochs = epochs.decimate(2)
# ---> 48 data, labels, _ = process_data(
#      49     epochs, id_pair, dim=dim, num=num, normalize_data=normalize_data
#      50 )
#      52 clf = LinearDiscriminantAnalysis()
#      53 cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=42)
#
# File ~/Martin/opm-thesis/opm_thesis/classifiers/csp/csp_functions.py:207, in process_data(epochs, id_pair, dim, num, normalize_data)
#     204 info = pair_epochs.info
#     206 if normalize_data:
# --> 207     mean = data_epochs.mean(axis=0, keepdims=True)
#     208     std = data_epochs.std(axis=0, keepdims=True)
#     209     data_epochs = (data_epochs - mean) / std
#
# File ~/Martin/opm-thesis/.venv/lib/python3.9/site-packages/numpy/core/_methods.py:168, in _mean(a, axis, dtype, out, keepdims, where)
#     164 arr = asanyarray(a)
#     166 is_float16_result = False
# --> 168 rcount = _count_reduce_items(arr, axis, keepdims=keepdims, where=where)
#     169 if rcount == 0 if where is True else umr_any(rcount == 0, axis=None):
#     170     warnings.warn("Mean of empty slice.", RuntimeWarning, stacklevel=2)
#
# File ~/Martin/opm-thesis/.venv/lib/python3.9/site-packages/numpy/core/_methods.py:72, in _count_reduce_items(arr, axis, keepdims, where)
#      70 if axis is None:
#      71     axis = tuple(range(arr.ndim))
# ---> 72 elif not isinstance(axis, tuple):
#      73     axis = (axis,)
#      74 items = 1
#
# KeyboardInterrupt:

# %% [markdown]
# ## Plotting CSP

# %%
from opm_thesis.classifiers.csp.csp_functions import plot_csp_patterns
id_pair = [8, 128]
plot_csp_patterns(id_pair, freqs[-1], data_dir, num=90, n_components=2, dim= "[X]")

# %%
plot_csp_patterns(id_pair, freqs[-1], data_dir, num=90, n_components=2, dim="[Y]")

# %%
plot_csp_patterns(id_pair,freqs[-1], data_dir, num=90, n_components=4, dim="[Z]")

# %% [markdown]
# ## Check classification of CSP

# %%
# Out:
# Frequency band:  ideal_beta
# Computing scores for [1, 2] in ideal_beta band...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       2 print("Frequency band: ", freq)
#       3 for id_pair in id_pairs:
# ----> 4     scores, eigenvalues = csp_classify(id_pair=id_pair, freq=freq, num=90, dim="[X]", data_dir=data_dir)
#
# File ~/Martin/opm-thesis/opm_thesis/classifiers/csp/csp_functions.py:79, in csp_classify(id_pair, freq, data_dir, num, dim, n_components, normalize_data)
#      77     score = clf.score(X_test_csp, y_test)
#      78     scores.append(score)
# ---> 79     eigenvalues.append(eigenvalue[:n_components])
#      81 score = np.mean(scores) * 100
#      82 eigenvalues = np.mean(eigenvalues, axis=1)
#
# NameError: name 'eigenvalue' is not defined

# %%
eigenvalues.shape
# Out:
# (5,)
