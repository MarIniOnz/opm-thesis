# %% [markdown]
# # Common Spatial Patterns (CSP)

# %%
from opm_thesis.classifiers.csp.csp_functions import csp_classify

data_dir = "/Users/martin.iniguez/Desktop/master-thesis/opm-thesis/data/digits_epochs/freq_bands/"
id_pairs = [[2**i, 2**j] for i in range(3, 8) for j in range(i + 1, 8)]
freqs = ["all_data", "mid_freq", "alpha", "beta", "low_gamma", "high_gamma"]

# %% [markdown]
# ## Plotting CSP

# %%
from opm_thesis.classifiers.csp.csp_functions import plot_csp_patterns

plot_csp_patterns(id_pairs[0], freqs[-2], data_dir, dim= "[X]")

# %% [markdown]
# ## Check classification of CSP

# %%
for freq in freqs:
  print("Frequency band: ", freq)
  for id_pair in id_pairs:
      csp_classify(id_pair, freq, data_dir)
# Out:
# Frequency band:  all_data
# Computing scores for [1, 2] in all_data band... Done. Average Score: 47.10%
# Computing scores for [1, 4] in all_data band... Done. Average Score: 49.03%
# Computing scores for [1, 8] in all_data band... Done. Average Score: 52.50%
# Computing scores for [1, 16] in all_data band... Done. Average Score: 51.88%
# Computing scores for [2, 4] in all_data band... Done. Average Score: 46.45%
# Computing scores for [2, 8] in all_data band... Done. Average Score: 43.23%
# Computing scores for [2, 16] in all_data band... Done. Average Score: 41.94%
# Computing scores for [4, 8] in all_data band... Done. Average Score: 45.62%
# Computing scores for [4, 16] in all_data band... Done. Average Score: 53.55%
# Computing scores for [8, 16] in all_data band... Done. Average Score: 45.00%
# Frequency band:  mid_freq
# Computing scores for [1, 2] in mid_freq band... Done. Average Score: 55.48%
# Computing scores for [1, 4] in mid_freq band... Done. Average Score: 50.32%
# Computing scores for [1, 8] in mid_freq band... Done. Average Score: 52.50%
# Computing scores for [1, 16] in mid_freq band... Done. Average Score: 43.12%
# Computing scores for [2, 4] in mid_freq band... Done. Average Score: 49.03%
# Computing scores for [2, 8] in mid_freq band... Done. Average Score: 43.87%
# Computing scores for [2, 16] in mid_freq band... Done. Average Score: 47.74%
# Computing scores for [4, 8] in mid_freq band... Done. Average Score: 52.50%
# Computing scores for [4, 16] in mid_freq band... Done. Average Score: 56.13%
# Computing scores for [8, 16] in mid_freq band... Done. Average Score: 46.88%
# Frequency band:  alpha
# Computing scores for [1, 2] in alpha band... Done. Average Score: 50.32%
# Computing scores for [1, 4] in alpha band... Done. Average Score: 50.97%
# Computing scores for [1, 8] in alpha band... Done. Average Score: 51.25%
# Computing scores for [1, 16] in alpha band... Done. Average Score: 49.38%
# Computing scores for [2, 4] in alpha band... Done. Average Score: 45.81%
# Computing scores for [2, 8] in alpha band... Done. Average Score: 47.74%
# Computing scores for [2, 16] in alpha band... Done. Average Score: 42.58%
# Computing scores for [4, 8] in alpha band... Done. Average Score: 50.00%
# Computing scores for [4, 16] in alpha band... Done. Average Score: 62.58%
# Computing scores for [8, 16] in alpha band... Done. Average Score: 46.88%
# Frequency band:  beta
# Computing scores for [1, 2] in beta band... Done. Average Score: 51.61%
# Computing scores for [1, 4] in beta band... Done. Average Score: 50.32%
# Computing scores for [1, 8] in beta band... Done. Average Score: 45.62%
# Computing scores for [1, 16] in beta band... Done. Average Score: 51.88%
# Computing scores for [2, 4] in beta band... Done. Average Score: 49.03%
# Computing scores for [2, 8] in beta band... Done. Average Score: 52.26%
# Computing scores for [2, 16] in beta band... Done. Average Score: 47.10%
# Computing scores for [4, 8] in beta band... Done. Average Score: 56.25%
# Computing scores for [4, 16] in beta band... Done. Average Score: 53.55%
# Computing scores for [8, 16] in beta band... Done. Average Score: 46.25%
# Frequency band:  low_gamma
# Computing scores for [1, 2] in low_gamma band... Done. Average Score: 44.52%
# Computing scores for [1, 4] in low_gamma band... Done. Average Score: 50.32%
# Computing scores for [1, 8] in low_gamma band... Done. Average Score: 44.38%
# Computing scores for [1, 16] in low_gamma band... Done. Average Score: 46.88%
# Computing scores for [2, 4] in low_gamma band... Done. Average Score: 58.71%
# Computing scores for [2, 8] in low_gamma band... Done. Average Score: 58.06%
# Computing scores for [2, 16] in low_gamma band... Done. Average Score: 41.29%
# Computing scores for [4, 8] in low_gamma band... Done. Average Score: 40.00%
# Computing scores for [4, 16] in low_gamma band... Done. Average Score: 47.10%
# Computing scores for [8, 16] in low_gamma band... Done. Average Score: 48.75%
# Frequency band:  high_gamma
# Computing scores for [1, 2] in high_gamma band... Done. Average Score: 47.74%
# Computing scores for [1, 4] in high_gamma band... Done. Average Score: 47.74%
# Computing scores for [1, 8] in high_gamma band... Done. Average Score: 54.37%
# Computing scores for [1, 16] in high_gamma band... Done. Average Score: 39.38%
# Computing scores for [2, 4] in high_gamma band... Done. Average Score: 48.39%
# Computing scores for [2, 8] in high_gamma band... Done. Average Score: 41.94%
# Computing scores for [2, 16] in high_gamma band... Done. Average Score: 40.00%
# Computing scores for [4, 8] in high_gamma band... Done. Average Score: 45.62%
# Computing scores for [4, 16] in high_gamma band... Done. Average Score: 45.16%
# Computing scores for [8, 16] in high_gamma band... Done. Average Score: 49.38%
